# %%
import threading
import time

# %%
N = 10
THINKING = 2
HUNGRY = 1
EATING = 0
times = 200

# %%
phil = [i for i in range(N)]

# %%
class Monitor:
    def __init__(self):
        self.state = [THINKING] * N

        self.phcond = [threading.Condition() for _ in range(N)]


    def test(self, phnum):
        with self.phcond[phnum]:
            if (self.state[(phnum + 1) % N] != EATING and
                self.state[(phnum + N - 1) % N] != EATING and
                    self.state[phnum] == HUNGRY):
                self.state[phnum] = EATING
                self.phcond[phnum].notify()

    def take_fork(self, phnum):
        with self.phcond[phnum]:

            self.state[phnum] = HUNGRY

            self.test(phnum)

            if self.state[phnum] != EATING:
                self.phcond[phnum].wait()
            print(f"Philosopher {phnum} is Eating")

    def put_fork(self, phnum):
        with self.phcond[phnum]:
            self.state[phnum] = THINKING

            self.test((phnum + 1) % N)
            self.test((phnum + N - 1) % N)

# %%
phil_object = Monitor()

# %%
def philosopher(phnum):
    c = 0
    while c < times:
        time.sleep(1)
        phil_object.take_fork(phnum)
        time.sleep(0.5)
        phil_object.put_fork(phnum)
        c += 1

# %%
def main():

    threads = []
    for i in range(N):
        t = threading.Thread(target=philosopher, args=(phil[i],))
        threads.append(t)
        t.start()
        print(f"Philosopher {i + 1} is thinking...")

    for i in range(N):
        threads[i].join()


if __name__ == "__main__":
    main()
# Out:
# Philosopher 1 is thinking...
# Philosopher 2 is thinking...
# Philosopher 3 is thinking...
# Philosopher 4 is thinking...
# Philosopher 5 is thinking...
# Philosopher 6 is thinking...
# Philosopher 7 is thinking...
# Philosopher 8 is thinking...
# Philosopher 9 is thinking...
# Philosopher 10 is thinking...
# Philosopher 0 is EatingPhilosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
#
# Philosopher 9 is EatingPhilosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
#
# Philosopher 3 is Eating
# Philosopher 4 is EatingPhilosopher 0 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
#
# Philosopher 7 is EatingPhilosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
#
# Philosopher 3 is Eating
# Philosopher 0 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 1 is EatingPhilosopher 7 is Eating
# Philosopher 9 is Eating
#
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is EatingPhilosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 8 is Eating
#
# Philosopher 4 is Eating
# Philosopher 5 is EatingPhilosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
#
# Philosopher 0 is EatingPhilosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
#
# Philosopher 2 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is EatingPhilosopher 4 is Eating
#
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 8 is Eating
# Philosopher 7 is EatingPhilosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
#
# Philosopher 9 is Eating
# Philosopher 6 is EatingPhilosopher 2 is Eating
#
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 1 is EatingPhilosopher 7 is Eating
#
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
#
# Philosopher 2 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 8 is EatingPhilosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
#
# Philosopher 9 is EatingPhilosopher 3 is Eating
# Philosopher 5 is Eating
#
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 6 is Eating
# Philosopher 7 is EatingPhilosopher 9 is Eating
# Philosopher 1 is Eating
#
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
#
# Philosopher 6 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 0 is EatingPhilosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
#
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is EatingPhilosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
#
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is EatingPhilosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
#
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is EatingPhilosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 8 is Eating
#
# Philosopher 6 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 2 is EatingPhilosopher 6 is Eating
#
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 7 is EatingPhilosopher 1 is Eating
# Philosopher 3 is Eating
#
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 7 is EatingPhilosopher 3 is Eating
# Philosopher 1 is Eating
#
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
#
# Philosopher 3 is EatingPhilosopher 1 is Eating
# Philosopher 7 is Eating
#
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 1 is EatingPhilosopher 7 is Eating
#
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 0 is EatingPhilosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
#
# Philosopher 4 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 2 is EatingPhilosopher 8 is Eating
#
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is EatingPhilosopher 3 is Eating
# Philosopher 1 is Eating
#
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 3 is EatingPhilosopher 1 is Eating
#
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is EatingPhilosopher 3 is Eating
# Philosopher 1 is Eating
#
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
#
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 1 is EatingPhilosopher 3 is Eating
# Philosopher 7 is Eating
#
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 8 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 8 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 8 is Eating
# Philosopher 1 is EatingPhilosopher 3 is Eating
#
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 3 is EatingPhilosopher 1 is Eating
#
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
#
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
#
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
#
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is EatingPhilosopher 6 is Eating
#
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
#
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
#
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is EatingPhilosopher 4 is Eating
# Philosopher 6 is Eating
#
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is EatingPhilosopher 5 is Eating
#
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 8 is EatingPhilosopher 4 is Eating
# Philosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
#
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
# Philosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 4 is EatingPhilosopher 6 is Eating
#
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 6 is EatingPhilosopher 4 is Eating
# Philosopher 8 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 3 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
#
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is EatingPhilosopher 4 is Eating
# Philosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is EatingPhilosopher 5 is Eating
#
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is EatingPhilosopher 5 is Eating
#
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 6 is Eating
# Philosopher 8 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
# Philosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is EatingPhilosopher 4 is Eating
#
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
#
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is EatingPhilosopher 5 is Eating
#
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
# Philosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
# Philosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 6 is EatingPhilosopher 8 is Eating
# Philosopher 4 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is EatingPhilosopher 6 is Eating
# Philosopher 4 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
# Philosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is EatingPhilosopher 6 is Eating
#
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is EatingPhilosopher 4 is Eating
#
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is EatingPhilosopher 4 is Eating
#
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
#
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is EatingPhilosopher 4 is Eating
#
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is EatingPhilosopher 7 is Eating
#
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
#
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
#
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 6 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 6 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 6 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 5 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 3 is EatingPhilosopher 9 is Eating
#
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 9 is Eating
# Philosopher 3 is Eating
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 9 is EatingPhilosopher 3 is Eating
#
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 0 is EatingPhilosopher 8 is Eating
#
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 3 is EatingPhilosopher 9 is Eating
#
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 0 is EatingPhilosopher 2 is Eating
#
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 3 is EatingPhilosopher 9 is Eating
#
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 2 is EatingPhilosopher 0 is Eating
#
# Philosopher 8 is Eating
# Philosopher 6 is Eating
# Philosopher 4 is Eating
# Philosopher 3 is EatingPhilosopher 9 is Eating
#
# Philosopher 5 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 0 is EatingPhilosopher 2 is Eating
#
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 3 is EatingPhilosopher 9 is Eating
#
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 1 is Eating
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 5 is Eating
# Philosopher 8 is EatingPhilosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 8 is EatingPhilosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
#
# Philosopher 6 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 2 is EatingPhilosopher 8 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 0 is Eating
#
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is EatingPhilosopher 8 is Eating
#
# Philosopher 0 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 8 is EatingPhilosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
#
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 0 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 3 is Eating
# Philosopher 9 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 0 is EatingPhilosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 4 is Eating
#
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 2 is EatingPhilosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
#
# Philosopher 6 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 8 is EatingPhilosopher 4 is Eating
# Philosopher 6 is Eating
#
# Philosopher 0 is Eating
# Philosopher 2 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is EatingPhilosopher 0 is Eating
#
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 2 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 1 is Eating
# Philosopher 5 is Eating
# Philosopher 2 is EatingPhilosopher 4 is Eating
#
# Philosopher 6 is Eating
# Philosopher 0 is Eating
# Philosopher 8 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 6 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is EatingPhilosopher 2 is Eating
#
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 2 is EatingPhilosopher 4 is Eating
#
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 1 is Eating
# Philosopher 7 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is EatingPhilosopher 6 is Eating
#
# Philosopher 2 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is EatingPhilosopher 2 is Eating
#
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 4 is Eating
# Philosopher 2 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
# Philosopher 3 is Eating
# Philosopher 7 is Eating
# Philosopher 1 is Eating
# Philosopher 9 is Eating
# Philosopher 5 is Eating
# Philosopher 2 is Eating
# Philosopher 4 is Eating
# Philosopher 6 is Eating
# Philosopher 8 is Eating
# Philosopher 0 is Eating
